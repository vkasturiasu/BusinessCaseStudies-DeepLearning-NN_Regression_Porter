# %% [markdown]
# ### Plan
#
# Keep things simple
# 1. Plan the project
# 2. Create a git repo and continuously push the code to git
# 3. Preprocessing and data exploration (EDA)
#     a. Understand the problem statement → 1 hour
#     b. Understand the data through visualization → 1 hour
#     c. Build a basic regression or classification model → 1 hour
#     d. Build evaluation metrics and understand where the error is → 1 hour
#     e. Explore the main model → 3 hours
#     f. Build the final model → 1 hour
